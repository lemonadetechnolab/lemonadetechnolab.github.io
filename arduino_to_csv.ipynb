# %%
import serial
import time
import csv
from bs4 import BeautifulSoup
import subprocess

ser = serial.Serial('/dev/cu.usbmodem14301')
ser.flushInput()

bar_pompw = 'lemonadetechnolab.github.io/barcode_item_pomp_water.html'
bar_pompa = 'lemonadetechnolab.github.io/barcode_item_pomp_afvalvat.html'
bar_pomps1 = 'lemonadetechnolab.github.io/barcode_item_pomp_aardbei.html'
bar_pomps2 = 'lemonadetechnolab.github.io/barcode_item_pomp_appel.html'
bar_pomps3 = 'lemonadetechnolab.github.io/barcode_item_pomp_sinaasappel.html'
bar_pompl = 'lemonadetechnolab.github.io/barcode_item_pomp_beker.html'

working_path = '/Users/kommunizm/Documents/Work/Uni/Technolab/clean_code/lemonadetechnolab.github.io'

time_0 = time.time()

# try:
#      output = subprocess.check_output(['./git_commit.sh'], cwd=working_path, stderr=subprocess.STDOUT)
# except subprocess.CalledProcessError as e:
#      print("Exception on process, rc=", e.returncode, "output=", e.output)

while True:
    current_time = round((time.time() - time_0) / 60, 2)
    ser_line = ser.readline()
    try:
        ser_line = ser_line.decode("utf-8")
        if ser_line.find("temperatuursensor") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_temp.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("sensor1") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_s1.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("sensor2") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_s2.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("sensor3") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_s3.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("sensorw") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_w.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("sensorl") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_l.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("turbiditysensor") != -1:
            turb_val = ser_line[ser_line.find(",")+1:ser_line.find(".")]
            print(ser_line)
            with open("lemonadetechnolab.github.io/datalog_turb.csv","a") as f:
                writer = csv.writer(f,delimiter=",")
                writer.writerow([current_time,turb_val])
        elif ser_line.find("pompw_high") != -1:
            with open(bar_pompw, "w") as f:
                turns = soup.span
                turns.string = str(int(turns.get_text()) + 1)
                f.write(str(soup))
        elif ser_line.find("pompa_high") != -1:
            with open(bar_pompa, "w") as f:
                turns = soup.span
                turns.string = str(int(turns.get_text()) + 1)
                f.write(str(soup))
        elif ser_line.find("pompl_high") != -1:
            with open(bar_pompl, "w") as f:
                turns = soup.span
                turns.string = str(int(turns.get_text()) + 1)
                f.write(str(soup))
        elif ser_line.find("pomps1_high") != -1:
            with open(bar_pomps1, "w") as f:
                turns = soup.span
                turns.string = str(int(turns.get_text()) + 1)
                f.write(str(soup))
        elif ser_line.find("pomps2_high") != -1:
            with open(bar_pomps2, "w") as f:
                turns = soup.span
                turns.string = str(int(turns.get_text()) + 1)
                f.write(str(soup))
        elif ser_line.find("pomps3_high") != -1:
            with open(bar_pomps3, "w") as f:
                turns = soup.span
                turns.string = str(int(turns.get_text()) + 1)
                f.write(str(soup))
        else:
            print(ser.readline())
    except:
        break
